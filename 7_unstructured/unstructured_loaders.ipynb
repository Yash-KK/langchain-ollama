# %%
print("Hello WOrld")
# Out:
# Hello WOrld

# %%
from pathlib import Path
from langchain_community.document_loaders import UnstructuredPowerPointLoader

path = Path("./data/ml_course.pptx")
loader = UnstructuredPowerPointLoader(path, mode="elements")
data = loader.load()

# %%
print(data[7])
# Out:
# page_content='Batch: In batch deployment, ML models process large volumes of data at scheduled intervals, ideal for tasks like end-of-day reporting or monthly analytics.' metadata={'source': 'data/ml_course.pptx', 'category_depth': 0, 'file_directory': 'data', 'filename': 'ml_course.pptx', 'last_modified': '2026-03-19T22:50:20', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation', 'parent_id': 'e16acab18bc7971064f2d06df301b796', 'category': 'ListItem', 'element_id': '36a2a2dc69a5a623ccc3eaa559f874eb'}
