# %%
print("Hello")
# Out:
# Hello

# %%
from markitdown import MarkItDown

md = MarkItDown()
result = md.convert("/home/yash/Documents/TekFrameworks/BlueOcean/TCS Analyst Reports/Analyst Report 2- Q1 FY26.pdf")
print(result.text_content)
# Out:
# India Equity Institutional Research II Result Update –Q1FY26 II31stJuly 2025 Page 1
# Tata Consumer Products Ltd.
# Q1FY26
# Tata Consumer Products
# Ltd.
# Result Update
# RRESeEAsRCuH AlNtA LUYSpT date Phone: +91-22-6696 55535 | 1Exst-5t1 9J uly 2025
# Ishank Gupta, fundamental-research2@devenchoksey.com www.devenchoksey.com
#
# India Equity Institutional Research  II           Result Update – Q1FY26             II 31st July 2025
# |     |     |     |     |     |     |     |     |     | Page 2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | ------ |
# Tata Consumer Products Ltd. Cost pressures in tea weighed on growth; margin rebound likely over H2FY26E
# CMP Target Potential Upside   Market Cap (INR Bn) Recommendation Sector
# | INR 1,073 | INR  1,192 | 11.1% |     |     |     | ACCUMULATE |     | Consumer |     |
# | --------- | ---------- | ----- | --- | --- | --- | ---------- | --- | -------- | --- |
# 1,065
# Result highlights
# SHARE PRICE PERFORMANCE
# ...

# %%
from markitdown import MarkItDown

md = MarkItDown()

input_file = "/home/yash/Desktop/Code/1. Langchain and Ollama/misc/Analyst Report 1- Q1 FY26.pdf"
output_file = "analyst_report_q1_fy26.md"

result = md.convert(input_file)

with open(output_file, "w", encoding="utf-8") as f:
    f.write(result.text_content)

print(f"Saved markdown to {output_file}")
# Out:
# Saved markdown to analyst_report_q1_fy26.md
